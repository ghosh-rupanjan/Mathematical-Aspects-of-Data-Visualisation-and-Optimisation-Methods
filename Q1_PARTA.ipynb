# %% [markdown]
# <a href="https://colab.research.google.com/github/ghosh-rupanjan/Mathematical-Aspects-of-Data-Visualisation-and-Optimisation-Methods/blob/main/Q1_PARTA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fastdtw
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy, scipy.spatial
from fastdtw import fastdtw
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-cp311-cp311-linux_x86_64.whl size=542085 sha256=d4433d696df819a367790d9647b2c41b16f58e2184595a3bf20e6a0c7ed3a2e8
#   Stored in directory: /root/.cache/pip/wheels/5c/8a/f6/fd3df9a9714677410a5ccbf3ca519e66db4a54a1c46ea95332
# Successfully built fastdtw
# ...

# %%
data = pd.read_csv("/content/total_acc_x_train.txt",sep =" ",on_bad_lines='warn',skipinitialspace=True, header = None)
#print(data)
data_np = data.to_numpy()
print(data_np.shape)
# Out:
# (7352, 128)

# %%
W_ = np.zeros((1000,1000))
np.shape(W_)
# Out:
# (1000, 1000)

# %%
data_ = np.zeros([])

# %%
for i in range (0,np.shape(W_)[0]):
  for j in range (0, np.shape(W_)[1]):
    W_[i,j] = fastdtw(data_np[i],data_np[j])[0]
pd.DataFrame(W_)
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.000000  0.155573  0.236379  0.242262  0.207211  0.193491  0.205443
# 1    0.155126  0.000000  0.221710  0.242907  0.192990  0.227024  0.218986
# 2    0.229164  0.221710  0.000000  0.173542  0.233368  0.242828  0.230450
# 3    0.248184  0.242653  0.173542  0.000000  0.257206  0.205060  0.254495
# 4    0.180395  0.192990  0.262123  0.257206  0.000000  0.181865  0.169365
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.778620  0.783066  0.745869  0.911610  0.935499  0.861011  0.899121
# 996  0.711328  0.743497  0.750100  0.801186  0.941478  0.854350  0.822308
# 997  0.882745  0.909566  0.896500  1.015158  0.975326  1.024298  1.018226
# 998  0.963592  0.937042  0.993325  1.004522  1.069720  0.972298  1.144359
# 999  0.789581  0.730773  0.685837  0.865833  0.805717  0.861764  0.933440
#
#           7         8         9    ...       990       991       992  \
# ...

# %%
W__ = pd.DataFrame(W_)
W__.to_csv("DRW Similarity")
